# %% [markdown]
# # Analysis of Nadini et. al.
# https://www.nature.com/articles/s41598-021-00053-8.pdf

# %% [markdown]
# ### Part 0: Doing some data preparation and preliminary analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
dataframe = pd.read_csv('Data_API.csv')
# Out:
# <ipython-input-4-98735392230c>:1: DtypeWarning: Columns (0,1,2,4,6,8,9,10,14,15,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataframe = pd.read_csv('Data_API.csv')

# %%
size = dataframe.shape
print("Dataframe Size", size)
print("Dataframe Head", dataframe.head())
# Out:
# Dataframe Size (6071027, 24)
# Dataframe Head   Smart_contract    ID_token  \
# 0            NaN  87094722.0
# 1            NaN  73044643.0
# 2            NaN  17107482.0
# 3            NaN  82230857.0
# 4            NaN  40925443.0
#
#                                     Transaction_hash  \
# 0  0xed9ff1c311a611e5c457ce0a49bbbb7ed55efca98842...
# 1  0xbc8412594ffa7382e8306215ece5b4e041fc641b1813...
# 2  0x92672baf5e9e23de230dee8e57ddf443ab6d5a336341...
# 3  0x3d157249e3083622c2d756f07a05caa3a76687288b32...
# 4  0xa892b3569dc8e6b3c7db93aade62372637ebbc61fb63...
#
#                                Seller_address Seller_username  \
# 0  0x76481caa104b5f6bccb540dae4cefaf1c398ebea             NaN
# 1  0x76481caa104b5f6bccb540dae4cefaf1c398ebea             NaN
# 2  0x76481caa104b5f6bccb540dae4cefaf1c398ebea             NaN
# 3  0x76481caa104b5f6bccb540dae4cefaf1c398ebea             NaN
# 4  0x76481caa104b5f6bccb540dae4cefaf1c398ebea             NaN
#
#                                 Buyer_address Buyer_username  \
# 0  0xe0fb7622091e3d9ef9b438471b10b9ea88c7cf6b            NaN
# 1  0x2c00d05ff7ffe93d77145dfe12aa56e622ae6f40            NaN
# 2  0xe0fb7622091e3d9ef9b438471b10b9ea88c7cf6b            NaN
# 3  0x2c00d05ff7ffe93d77145dfe12aa56e622ae6f40            NaN
# 4  0x2c00d05ff7ffe93d77145dfe12aa56e622ae6f40            NaN
#
#                                   Image_url_1 Image_url_2 Image_url_3  ...  \
# 0   https://card.godsunchained.com/?id=33&q=4         NaN         NaN  ...
# 1   https://card.godsunchained.com/?id=79&q=4         NaN         NaN  ...
# 2   https://card.godsunchained.com/?id=33&q=4         NaN         NaN  ...
# 3  https://card.godsunchained.com/?id=227&q=4         NaN         NaN  ...
# 4   https://card.godsunchained.com/?id=62&q=4         NaN         NaN  ...
#
#   Name  Description     Collection         Market     Datetime_updated  \
# 0  NaN          NaN  Godsunchained  Godsunchained  2019-11-30 00:00:00
# 1  NaN          NaN  Godsunchained  Godsunchained  2019-11-30 00:00:00
# 2  NaN          NaN  Godsunchained  Godsunchained  2019-11-30 00:00:00
# 3  NaN          NaN  Godsunchained  Godsunchained  2019-11-30 00:00:00
# 4  NaN          NaN  Godsunchained  Godsunchained  2019-11-30 00:00:00
#
#   Datetime_updated_seconds Permanent_link             Unique_id_collection  \
# 0      2019-11-30 23:59:33            NaN  ('Godsunchained', '87094722.0')
# 1      2019-11-30 23:59:33            NaN  ('Godsunchained', '73044643.0')
# 2      2019-11-30 23:59:33            NaN  ('Godsunchained', '17107482.0')
# 3      2019-11-30 23:59:33            NaN  ('Godsunchained', '82230857.0')
# 4      2019-11-30 23:58:44            NaN  ('Godsunchained', '40925443.0')
#
#   Collection_cleaned Category
# 0      Godsunchained    Games
# 1      Godsunchained    Games
# 2      Godsunchained    Games
# 3      Godsunchained    Games
# 4      Godsunchained    Games
#
# [5 rows x 24 columns]

# %%
print("Columns", dataframe.columns)

# getting all unique values in the column called "Collection"
print("Unique Values in Category", dataframe['Category'].unique())
# Out:
# Columns Index(['Smart_contract', 'ID_token', 'Transaction_hash', 'Seller_address',
#        'Seller_username', 'Buyer_address', 'Buyer_username', 'Image_url_1',
#        'Image_url_2', 'Image_url_3', 'Image_url_4', 'Price_Crypto', 'Crypto',
#        'Price_USD', 'Name', 'Description', 'Collection', 'Market',
#        'Datetime_updated', 'Datetime_updated_seconds', 'Permanent_link',
#        'Unique_id_collection', 'Collection_cleaned', 'Category'],
#       dtype='object')
# Unique Values in Category ['Games' 'Art' 'Other' 'Collectible' 'Metaverse' 'Utility']

# %% [markdown]
# ### Part 1: Description of NFT Marketplace
# #### 1.1 Replicating Figure 1

# %%
# Correcting the datetime format
dataframe['Datetime_updated'] = pd.to_datetime(dataframe['Datetime_updated'])

# Creating new dataframes for each unique value in the column called "Category"
art_data = dataframe[dataframe['Category'] == 'Art']
collectible_data = dataframe[dataframe['Category'] == 'Collectible']
games_data = dataframe[dataframe['Category'] == 'Games']
metaverse_data = dataframe[dataframe['Category'] == 'Metaverse']
other_data = dataframe[dataframe['Category'] == 'Other']
utility_data = dataframe[dataframe['Category'] == 'Utility']

# %%
# A function to plot price data on a log scale
def plot_price_data(current_dataframe, title, ax=None):
    if ax is None:
        fig = plt.figure()
        ax = fig.add_subplot(111)
        ax.set_yscale('log')
        ax.set_title(title)
    dataframe_day = current_dataframe.groupby(current_dataframe['Datetime_updated'].dt.date).sum()
    ax.plot(dataframe_day.index, dataframe_day['Price_USD'])

# %%
# Creating a new dataframe of day vs Price_USD for the category "Art" on a log scale
plot_price_data(art_data, "Art")
plot_price_data(collectible_data, "Collectible")
plot_price_data(games_data, "Games")
plot_price_data(metaverse_data, "Metaverse")
plot_price_data(other_data, "Other")
plot_price_data(utility_data, "Utility")

# %%
# plotting a list of dataframes on the same graph
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_yscale('log')
ax.set_title("All Categories")

plot_price_data(art_data, "Art", ax)
plot_price_data(collectible_data, "Collectible", ax)
plot_price_data(games_data, "Games", ax)
plot_price_data(metaverse_data, "Metaverse", ax)
plot_price_data(other_data, "Other", ax)
plot_price_data(utility_data, "Utility", ax)

# %%
# Summing the price data for each unique Collection_cleaned in each category
art_data_sum = art_data.groupby(art_data['Collection']).sum()
collectible_data_sum = collectible_data.groupby(collectible_data['Collection']).sum()
games_data_sum = games_data.groupby(games_data['Collection']).sum()
metaverse_data_sum = metaverse_data.groupby(metaverse_data['Collection']).sum()
other_data_sum = other_data.groupby(other_data['Collection']).sum()
utility_data_sum = utility_data.groupby(utility_data['Collection']).sum()

# getting the top 10 collections by price
art_data_sum_top10 = art_data_sum.nlargest(10, 'Price_USD')
collectible_data_sum_top10 = collectible_data_sum.nlargest(10, 'Price_USD')
games_data_sum_top10 = games_data_sum.nlargest(10, 'Price_USD')
metaverse_data_sum_top10 = metaverse_data_sum.nlargest(10, 'Price_USD')
other_data_sum_top10 = other_data_sum.nlargest(10, 'Price_USD')
utility_data_sum_top10 = utility_data_sum.nlargest(10, 'Price_USD')

# %% [markdown]
# #### 1.2 Replicating Figure 1 (The Top NFT Collections per Category)

# %%
print("Art data top 10", art_data_sum_top10)
print("Collectible data top 10", collectible_data_sum_top10)
print("Games data top 10", games_data_sum_top10)
print("Metaverse data top 10", metaverse_data_sum_top10)
print("Other data top 10", other_data_sum_top10)
print("Utility data top 10", utility_data_sum_top10)
# Out:
# Art data top 10                         Price_Crypto     Price_USD
# Collection
# Cryptopunks             1.496969e+05  2.634816e+08
# Rarible                 1.917020e+06  8.212941e+07
# Hashmasks               5.478190e+05  4.741509e+07
# Cryptokitties           1.196038e+05  3.954234e+07
# Superrare               3.566416e+04  3.522466e+07
# Art-blocks              3.213218e+04  1.570892e+07
# Wrapped-mooncatsrescue  3.222499e+04  1.123693e+07
# Autoglyphs              8.279856e+03  9.168126e+06
# 1111-by-kevin-abosch    3.953223e+03  7.773867e+06
# Wrapped-cryptopunks     8.561098e+03  6.458603e+06
# Collectible data top 10                                          Price_Crypto     Price_USD
# Collection
# Sorare                                   4.069990e+04  4.856276e+07
# mlb.topps                                3.303557e+07  6.208778e+06
# Bullrunbabestoken                        3.006804e+03  4.063449e+06
# Waifusion                                6.652062e+03  3.861343e+06
# Bccg                                     2.422827e+05  3.846065e+06
# Polkapets                                1.620730e+05  3.459985e+06
# rplanet                                  1.441554e+07  2.928511e+06
# Nftboxes                                 1.401545e+03  2.420533e+06
# Superfarm                                1.158240e+03  2.412546e+06
# Rob-gronkowski-championship-series-nfts  1.080033e+03  2.056583e+06
# Games data top 10                 Price_Crypto     Price_USD
# Collection
# Axie            1.460495e+05  1.968207e+07
# alien.worlds    6.479487e+07  1.209047e+07
# Elliotrades     3.374985e+03  6.063674e+06
# Gods-unchained  2.078417e+06  5.681750e+06
# Polkamon        4.511258e+04  5.043126e+06
# Mycryptoheroes  2.403574e+04  4.246839e+06
# F1-delta-time   1.252364e+07  2.934267e+06
# Godsunchained   9.213489e+03  2.113385e+06
# kogsofficial    3.359183e+07  1.843894e+06
# Chainguardians  1.698789e+05  1.803570e+06
# Metaverse data top 10                          Price_Crypto     Price_USD
# Collection
# Decentraland             3.424449e+08  3.311626e+07
# Somnium-space            5.533712e+05  1.704427e+07
# Cryptovoxels             1.426084e+04  7.379105e+06
# Sandbox                  4.685870e+06  5.563855e+06
# Mirandus                 1.192547e+07  1.471124e+06
# Polka-city-asset         1.760474e+04  6.228436e+05
# Decentraland-wearables   3.674150e+06  6.065794e+05
# Wallem-skins             4.899391e+02  5.878210e+05
# Glewme-city-real-estate  2.276523e+04  4.834433e+05
# Gego-dego                4.700197e+03  2.921974e+05
# Other data top 10                            Price_Crypto     Price_USD
# Collection
# Ens                         8881.767637  2.464417e+06
# Trevorjonesart             21236.357400  7.182403e+05
# Nonfungibleapes              568.813400  2.167777e+05
# Lf2                           66.108000  1.204042e+05
# Punkoutfits                   59.782316  1.068195e+05
# Chonknft                     275.353900  1.064272e+05
# Marblecards               164328.938063  1.063882e+05
# Superchief-gallery-nifty      51.580000  1.055291e+05
# Project-senpai                53.472300  1.027259e+05
# Dystopianpunks                55.038900  1.026446e+05
# Utility data top 10                              Price_Crypto     Price_USD
# Collection
# Ether-cards-founder          68639.890128  2.357171e+06
# Yinsurenft                    5247.724900  1.968948e+06
# Urbit-id                     83564.813335  1.836620e+06
# Pgfks                        45806.777868  1.110028e+06
# Unstoppable-domains          11930.915935  6.578883e+05
# Methodnft                      276.685021  5.884530e+05
# Unisocks                       213.818900  1.911004e+05
# Terravirtuanft                  59.622195  1.938931e+04
# Unstoppable-domains-animals     55.269189  1.472972e+04
# terrafyed123                    89.910000  2.186284e+01

# %% [markdown]
# Note: We could not replicate figure 3 since that deals with secondary trades among the NFTs. The dataset provided by this paper does not contain secondary trades so this seems to not be possible for now.

# %% [markdown]
# ### Part 2: Trader Analysis

# %% [markdown]
# #### 2.1 Trader Landscape for Art
#
# Note: Since the size of the dataset was quite large, I wasn't able to replicate the network including the entire dataset, but used a subset of data to still get a sense of the network. We were able to get to a similar conclusion as the original paper.

# %%
import networkx as nx

def create_graph(art_data, first_collection, second_collection):
    # Making a networkx graph of the traders that traded in Cryptopunks and Rarible group
    art_trader_data = art_data[art_data["Collection"].isin([first_collection, second_collection])].head(1800)
    # Adding color for different Collection
    art_trader_data["color"] = art_trader_data["Collection"].apply(lambda x: "black" if x == first_collection else "blue")

    art_graph = nx.from_pandas_edgelist(art_trader_data, source="Seller_address", target="Buyer_address", edge_attr=["color", "Price_USD"])

    # Printing some information of the graph
    print("Art graph nodes", art_graph.number_of_nodes())
    print("Art graph edges", art_graph.number_of_edges())

    colors = nx.get_edge_attributes(art_graph, "color").values()
    weights = nx.get_edge_attributes(art_graph, "Price_USD").values()
    nx.draw(art_graph, pos=nx.spring_layout(art_graph), with_labels=False, node_size=5, node_color='red', edge_color=colors, width=3)

# %%
create_graph(art_data, "Cryptopunks", "Rarible")
# Out:
# Art graph nodes 484
# Art graph edges 1017

# %%
create_graph(art_data, "Crpytokitties", "Superrare")
# Out:
# Art graph nodes 308
# Art graph edges 1040

# %% [markdown]
# As you can see in the above images, if you are comparing two giants in the same category, you will see a higher number of trades as well as interactions between the two. Nevertheless, most of the interactions are intra-collection as opposed to inter-collection. If you compare a giant like Cryptokitties to a smaller collection like Superrare, you will not see too many interactions between the two since the collections are likely to be separate.

# %% [markdown]
# ### Part 3: Visual Analysis

# %% [markdown]
# ### Part 4: Model

# %%
df_sorted = dataframe.sort_values("Datetime_updated_seconds")
df_sorted = df_sorted.reset_index()

# %%
primary_sales = set()
collections = {}
prior_sales = []
mean_price = []
p_resale = []
is_primary = []
for index, row in df_sorted.iterrows():       
    if row["Collection_cleaned"] in collections.keys():
        curr_elem = collections[row["Collection_cleaned"]]
        mean_price.append(curr_elem[2])
        
        num_sold = curr_elem[0]
        curr_elem[2] = (curr_elem[2] * num_sold + row["Price_USD"])/(num_sold + 1)
        
        n = curr_elem[0]
        s = curr_elem[1]        
        p = 0.5/n + s*n/(n + 1)
        p_resale.append(p)
        
        curr_elem[0] += 1
    else:
        collections[row["Collection_cleaned"]] = [1,0, row["Price_USD"]]
        p_resale.append(0.5)
        mean_price.append(0)
        
    prior_sales.append(collections[row["Collection_cleaned"]])
    
    if row["Unique_id_collection"] in primary_sales:
        is_primary.append(False)
        collections[row["Collection_cleaned"]][1] += 1
    else:
        primary_sales.add(row["Unique_id_collection"])
        is_primary.append(True)    
        
        
df_sorted["Primary_sale"] = is_primary
df_sorted["Prior Sales"] = prior_sales
df_sorted["P_resale"] = p_resale
df_sorted["Mean_price"] = mean_price

# %%
FG = nx.from_pandas_edgelist(df_sorted, source="Seller_address", target="Buyer_address")
degree_dict=nx.degree_centrality(FG)
df_sorted["Seller_centrality"] = df_sorted["Seller_address"].map(degree_dict)
df_sorted["Buyer_centrality"] = df_sorted["Buyer_address"].map(degree_dict)

# %%
pg_centrality = nx.pagerank(FG)
df_sorted["Seller_PG_centrality"] = df_sorted["Seller_address"].map(pg_centrality)
df_sorted["Buyer_PG_centrality"] = df_sorted["Buyer_address"].map(pg_centrality)

# %%
df_sorted = df_sorted.dropna()
primary_sales = df_sorted[df_sorted["Primary_sale"] == True]
secondary_sales = df_sorted[df_sorted["Primary_sale"] == False]

# %%
y = df_sorted["Price_USD"]
x = df_sorted[["Category", "Mean_price",
               "Seller_centrality", "Buyer_centrality", "Seller_PG_centrality", "Buyer_PG_centrality",
               "P_resale"]]

x["P_resale"] = (x["P_resale"] - x["P_resale"].mean())/x["P_resale"].std()

x = pd.get_dummies(x, columns=["Category"], drop_first=True)
x = sm.add_constant(x)

est=sm.OLS(y, x, missing="drop")
est = est.fit()
est.summary()
# Out:
# <ipython-input-194-a8f24c5e0014>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x["P_resale"] = (x["P_resale"] - x["P_resale"].mean())/x["P_resale"].std()
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Price_USD   R-squared:                       0.072
# Model:                            OLS   Adj. R-squared:                  0.072
# Method:                 Least Squares   F-statistic:                     2160.
# Date:                Thu, 05 May 2022   Prob (F-statistic):               0.00
# Time:                        09:57:21   Log-Likelihood:            -3.0063e+06
# No. Observations:              305188   AIC:                         6.013e+06
# Df Residuals:                  305176   BIC:                         6.013e+06
# Df Model:                          11
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                  778.3782     20.983     37.095      0.000     737.252     819.505
# Mean_price               0.7945      0.006    133.374      0.000       0.783       0.806
# Seller_centrality    -7.112e+04   2.23e+04     -3.186      0.001   -1.15e+05   -2.74e+04
# Buyer_centrality     -1.662e+04   2.47e+04     -0.672      0.502   -6.51e+04    3.19e+04
# Seller_PG_centrality  3.544e+05   1.76e+05      2.018      0.044    1.03e+04    6.99e+05
# Buyer_PG_centrality  -1.232e+05    2.7e+05     -0.457      0.648   -6.52e+05    4.06e+05
# P_resale              -126.8054     10.017    -12.659      0.000    -146.438    -107.173
# Category_Collectible  -673.7224     32.927    -20.461      0.000    -738.259    -609.185
# Category_Games        -683.8025     24.049    -28.433      0.000    -730.938    -636.667
# Category_Metaverse    -584.2247     41.435    -14.100      0.000    -665.436    -503.013
# Category_Other        -760.1787     37.337    -20.360      0.000    -833.358    -686.999
# Category_Utility      -703.3546     77.766     -9.044      0.000    -855.775    -550.934
# ==============================================================================
# Omnibus:                  1168112.024   Durbin-Watson:                   1.960
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):    2562412429696.294
# Skew:                          88.859   Prob(JB):                         0.00
# Kurtosis:                   14197.247   Cond. No.                     4.89e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.89e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
x_ = x.reset_index()
x_1 = x_.drop(["index", "const"], axis = 1)

reg = LinearRegression().fit(x_1, y)
reg.score(x_1, y)
# Out:
# 0.07222807773722761

# %%
df_sorted[["Price_USD", "Name", "Collection_cleaned", "Datetime_updated_seconds", "Category", "Unique_id_collection", "Primary_sale", "Seller_centrality", "Buyer_centrality", "Seller_PG_centrality", "Buyer_PG_centrality"]].tail(8)
# Out:
#            Price_USD            Name Collection_cleaned  \
# 6071019  1937.295410  Subscapes #467                Art
# 6071020     0.121905             NaN              Alien
# 6071021     7.259000             NaN           Mlb.topp
# 6071022     0.082960             NaN              Alien
# 6071023     0.072590             NaN              Alien
# 6071024     0.076738             NaN              Alien
# 6071025     0.076738             NaN              Alien
# 6071026     0.091256             NaN              Alien
#
#         Datetime_updated_seconds     Category  \
# 6071019      2021-04-27 23:59:51          Art
# 6071020      2021-04-27 23:59:53        Games
# 6071021      2021-04-27 23:59:55  Collectible
# 6071022      2021-04-27 23:59:55        Games
# 6071023      2021-04-27 23:59:55        Games
# 6071024      2021-04-27 23:59:55        Games
# 6071025      2021-04-27 23:59:56        Games
# 6071026      2021-04-27 23:59:57        Games
#
#                       Unique_id_collection  Primary_sale  Seller_centrality  \
# 6071019         ('Art-blocks', '53000467')          True           0.000073
# 6071020  ('alien.worlds', '1099529899632')         False           0.016022
# 6071021     ('mlb.topps', '1099525620985')         False           0.002629
# 6071022  ('alien.worlds', '1099529894344')          True           0.000520
# 6071023  ('alien.worlds', '1099529899954')          True           0.000002
# 6071024  ('alien.worlds', '1099529899571')          True           0.000002
# 6071025  ('alien.worlds', '1099529899986')          True           0.000002
# 6071026  ('alien.worlds', '1099527768250')          True           0.000398
#
#          Buyer_centrality  Seller_PG_centrality  Buyer_PG_centrality
# 6071019          0.000002          7.931209e-06         4.526849e-07
# 6071020          0.000006          3.337751e-03         2.555026e-06
# 6071021          0.000283          7.866514e-05         9.340809e-06
# 6071022          0.002265          4.768883e-05         3.791851e-04
# 6071023          0.000906          4.095701e-07         2.089424e-04
# 6071024          0.000906          4.095701e-07         2.089424e-04
# 6071025          0.000906          4.095701e-07         2.089424e-04
# 6071026          0.000002          4.300764e-05         5.458773e-07

# %%
dataframe.columns
# Out:
# Index(['Smart_contract', 'ID_token', 'Transaction_hash', 'Seller_address',
#        'Seller_username', 'Buyer_address', 'Buyer_username', 'Image_url_1',
#        'Image_url_2', 'Image_url_3', 'Image_url_4', 'Price_Crypto', 'Crypto',
#        'Price_USD', 'Name', 'Description', 'Collection', 'Market',
#        'Datetime_updated', 'Datetime_updated_seconds', 'Permanent_link',
#        'Unique_id_collection', 'Collection_cleaned', 'Category'],
#       dtype='object')
